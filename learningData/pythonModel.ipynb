# %%
import pandas as pd

# %%
data=pd.read_csv("training_small.csv")
data=data.drop_duplicates()

# %%
data.head()
# Out:
#    NumOfNodes  NumOfArcs  VolumeOfDemands  timeSurplus  Arc0  Arc1  Arc2  \
# 0          75        225              409           11     1     4  0.07
# 1          75        225              409           12     4     3  0.18
# 2          75        225              409            7     4     4  0.15
# 3          75        225              409            7     2     4  0.12
# 4          75        225              409           12     5     3  0.28
#
#    Arc3  Arc4  Arc5 ...  Arc23  Arc24  Arc25  iIfOrigin  jIfDestination  \
# 0  0.04  0.18  0.10 ...      3      3      3          1               1
# 1  0.10  0.05  0.17 ...      3      3      3          1               1
# 2  0.09  0.12  0.22 ...      3      3      3          1               0
# 3  0.16  0.28  0.23 ...      3      3      3          0               1
# 4  0.23  0.07  0.17 ...      3      3      3          1               1
#
#    rSPCount  iflpCover  lpPercent  timeDiff  y
# 0         1          0       0.00         3  1
# 1         1          0       0.00         6  1
# 2         1          0       0.00        15  1
# 3         1          0       0.00        15  1
# 4         1          1       0.32         0  1
#
# [5 rows x 37 columns]

# %%
# from sklearn.model_selection import train_test_split
# train_data,test_data=train_test_split(data,train_size=0.67,random_state=0)

# y_train=train_data.y
# train_data=train_data.drop(['y'],axis=1)
# x_train=train_data.as_matrix()

# y_test=test_data.y
# test_data=test_data.drop(['y'],axis=1)
# x_test=test_data.as_matrix()
# print(train_data.columns.tolist())

# %%
from sklearn.linear_model import LogisticRegressionCV
y=data.y
x=data.as_matrix()
x=x[:,0:x.shape[1]-1]

clf=LogisticRegressionCV(cv=10,random_state=0,penalty="l1",solver="liblinear").fit(x,y)

coef_list=clf.coef_
col_names=data.columns.values.tolist()

for i in range(len(coef_list[0])):
    print(col_names[i])
    print(coef_list[0][i])
    print()
# Out:
# NumOfNodes
# -0.0272855812897
#
# NumOfArcs
# 0.0400351577683
#
# VolumeOfDemands
# 0.0196386221936
#
# timeSurplus
# -0.279127153694
#
# Arc0
# -0.178841559273
#
# Arc1
# 0.0203441103506
#
# Arc2
# -0.00904014690703
#
# Arc3
# -1.33419839998
#
# Arc4
# 2.17828731393
#
# Arc5
# 6.64492828841
#
# Arc6
# -0.077151679602
#
# Arc7
# -3.24581687241
#
# Arc8
# 5.50368387673
#
# Arc9
# 2.66366787282
#
# Arc10
# -0.540696136576
#
# Arc11
# -0.61277834764
#
# Arc12
# 4.69592378005
#
# Arc13
# 2.9068448359
#
# Arc14
# 0.0
#
# Arc15
# 0.193919531519
#
# Arc16
# -0.518060576752
#
# Arc17
# -0.882411372312
#
# Arc18
# -0.268555126834
#
# Arc19
# -0.703436680291
#
# Arc20
# 0.0945731583344
#
# Arc21
# -0.201184246058
#
# Arc22
# -0.120349445014
#
# Arc23
# -1.27077391295
#
# Arc24
# 0.0604331348008
#
# Arc25
# 0.218367738785
#
# iIfOrigin
# 1.68940706106
#
# jIfDestination
# 1.93877820224
#
# rSPCount
# 2.39845410196
#
# iflpCover
# -0.0625776983694
#
# lpPercent
# 0.0623147050542
#
# timeDiff
# -0.0869758436567

# %%
print(clf.score(x,y))
# Out:
# 0.914163090129

# %%
import numpy as np
np.exp(clf.coef_)
# Out:
# array([[  9.73083307e-01,   1.04084737e+00,   1.01983273e+00,
#           7.56443712e-01,   8.36238383e-01,   1.02055246e+00,
#           9.91000592e-01,   2.63369208e-01,   8.83116828e+00,
#           7.68874908e+02,   9.25749426e-01,   3.89367450e-02,
#           2.45595010e+02,   1.43488224e+01,   5.82342721e-01,
#           5.41843347e-01,   1.09499916e+02,   1.82989711e+01,
#           1.00000000e+00,   1.21399859e+00,   5.95674694e-01,
#           4.13783921e-01,   7.64483278e-01,   4.94881628e-01,
#           1.09918958e+00,   8.17761748e-01,   8.86610561e-01,
#           2.80614367e-01,   1.06229656e+00,   1.24404447e+00,
#           5.41626824e+00,   6.95025398e+00,   1.10061488e+01,
#           9.39340075e-01,   1.06429723e+00,   9.16699239e-01]])
